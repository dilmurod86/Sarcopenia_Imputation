# %%
import pandas as pd
from sklearn.impute import KNNImputer

# Load your dataset
df = pd.read_csv('/kaggle/input/misseddatasarcopenia/cleaned_dataset(Current97).csv')  # Update this with the path to your dataset

# Initialize the KNNImputer
# Set n_neighbors to your preferred number, e.g., 5
imputer = KNNImputer(n_neighbors=5, add_indicator=False)

# Fit the imputer and transform the dataset to impute missing values
# The fit_transform method returns a numpy array, so we need to convert it back to a DataFrame
imputed_data = imputer.fit_transform(df)
imputed_df = pd.DataFrame(imputed_data, columns=df.columns)

# Ensure the original non-missing values remain unchanged by copying them from the original dataframe
imputed_df[df.notnull()] = df[df.notnull()]

# Save the imputed dataset to a new CSV file
imputed_df.to_csv('imputed_datasetKNN.csv', index=False)

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# Load your dataset
df = pd.read_csv('/kaggle/input/misseddata20/data_with_missing20.csv')  # Update this with the path to your dataset

# Initialize the KNNImputer
# Set n_neighbors to your preferred number, e.g., 5
imputer = KNNImputer(n_neighbors=5, add_indicator=False)

# Fit the imputer and transform the dataset to impute missing values
# The fit_transform method returns a numpy array, so we need to convert it back to a DataFrame
imputed_data = imputer.fit_transform(df)
imputed_df = pd.DataFrame(imputed_data, columns=df.columns)

# Ensure the original non-missing values remain unchanged by copying them from the original dataframe
imputed_df[df.notnull()] = df[df.notnull()]

# Save the imputed dataset to a new CSV file
imputed_df.to_csv('imputed_datasetKNN20.csv', index=False)
